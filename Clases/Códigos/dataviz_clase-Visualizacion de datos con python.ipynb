# %%
import pandas as pd

from google.colab import drive 
drive.mount('/content/gdrive')

import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Dataviz/data_TV.csv')
df
# Out:
#      first_air_date origin_country original_language               name  \
# 0        2021-09-03             US                en  The D'Amelio Show
# 1        2008-01-20             US                en       Breaking Bad
# 2        2021-11-06             US                en             Arcane
# 3        2013-12-02             US                en     Rick and Morty
# 4        2022-04-14             US                en    The Kardashians
# ...             ...            ...               ...                ...
# 2612     2002-06-11             US                en      American Idol
# 2613     2000-07-05             US                en        Big Brother
# 2614     1997-03-31             GB                en        Teletubbies
# 2615     1985-02-19             GB                en         EastEnders
# 2616     2006-10-09             CA                fr             La Job
#
#       popularity  vote_average  vote_count  \
# 0         30.104           9.0        3071
# ...

# %%
df['first_air_year'] = pd.to_datetime(df['first_air_date'],format='%Y-%m-%d').dt.year
df['first_air_year']
# Out:
# 0       2021.0
# 1       2008.0
# 2       2021.0
# 3       2013.0
# 4       2022.0
#          ...
# 2612    2002.0
# 2613    2000.0
# 2614    1997.0
# 2615    1985.0
# 2616    2006.0
# Name: first_air_year, Length: 2617, dtype: float64

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt



plt.xlabel("first_air_year")
plt.xlabel("first_air_year")

plt.ylabel("vote_count")  # add Y-axis label
plt.ylabel("vote_count")

plt.title("Votes per year TV SHOW")  # add title
plt.title("Votes per year TV show")



var = df.groupby('first_air_year').vote_count.sum()
var = df.groupby('first_air_year').vote_count.sum()



var.plot(kind="line")
var.plot(kind="line")

# %%
df['original_language'].value_counts(ascending=True)
df['original_langues'].values_counts](ascending=True)
# Out:
# nl       1
# tl       1
# is       2
# pl       2
# he       2
# ca       2
# th       2
# ar       2
# hi       4
# ru       5
# no       5
# sv       6
# da       6
# zh      10
# it      11
# de      13
# tr      19
# fr      20
# pt      22
# ko      99
# es     301
# ja     397
# en    1685
# Name: original_language, dtype: int64

# %%
# Creating dataset
var = df.groupby('original_language').vote_count.count()
var = df.groupby('original_language').vote_count.count()

labels_pie = var.index
 
# Creating plot

plt.pie(var, labels = labels_pie)
 
# show plot
plt.show()

# %%
fig = plt.figure(figsize = (15, 7))

var2 = df.groupby('original_language').vote_count.count()
plt.bar(labels_pie,var2, color ='blue',width = 0.8)
# Out:
# <BarContainer object of 23 artists>
